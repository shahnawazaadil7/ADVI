# %% [markdown]
# # Naive Bayes
#
# Naive Bayes is used in NLP to analyse the sentiment and to train speech to the model which was trained under NLP.
#
# 1. All words are converted to histograms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Prior Probability P(A)**: Probabilty of an event before evidence is see.
# 2. **Marginal Probability P(B)** : Probability of evidence.
# 3. **Prosterior Probabilty P(A|B)** : Probability of an event after evidence is seen.
# 4. **Likelihood probabilty P(B|A)** : hypothesis will come true based on the evidence.

# %% [markdown]
# Black Box :
